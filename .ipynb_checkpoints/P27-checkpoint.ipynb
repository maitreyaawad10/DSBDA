# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('./DATASETS/archive/Admission_Predict_Ver1.1.csv')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA
# 0           1        337          118                  4  4.5   4.5  9.65  \
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.shape
# Out:
# (500, 9)

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (500, 9)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 12))
# correlation_matrix = df[~df['Chance of Admit ']].corr()
continuous_columns = ['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA', 'Research', 'Chance of Admit ']

# Create a correlation matrix
correlation_matrix = df[continuous_columns].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
# Find the column with the highest correlation with the target variable
target_column = df['Chance of Admit ']
highest_correlation_column = correlation_matrix[target_column].idxmax()

# Build a linear regression model using the column with the highest correlation
from sklearn.linear_model import LinearRegression

X = df[highest_correlation_column].values.reshape(-1, 1)
y = df[target_column].values

model = LinearRegression()
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_18134/192264591.py in <module>
#       1 # Find the column with the highest correlation with the target variable
#       2 target_column = df['Chance of Admit ']
# ----> 3 highest_correlation_column = correlation_matrix[target_column].idxmax()
#       4
#       5 # Build a linear regression model using the column with the highest correlation
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
# ...
