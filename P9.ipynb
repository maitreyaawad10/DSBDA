# %%
import pandas as pd

# %%
df = pd.read_csv("./DATASETS/dataset_Facebook.csv", sep=';')

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0            139441   Photo         2          12             4          3  \
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions
# 0   0.0                       2752                             5091  \
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers
# ...

# %% [markdown]
# # CREATING SUBSETS

# %%
df['Type'].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %% [markdown]
# ## PHOTO SUBSET

# %%
photo_subset = df[df['Type'] == 'Photo'].loc[0:20]

# %%
photo_subset
# Out:
#     Page total likes   Type  Category  Post Month  Post Weekday  Post Hour
# 0             139441  Photo         2          12             4          3  \
# 2             139441  Photo         3          12             3          3
# 3             139441  Photo         2          12             2         10
# 4             139441  Photo         2          12             2          3
# 6             139441  Photo         3          12             1          3
# 7             139441  Photo         3          12             7          9
# 9             139441  Photo         3          12             6         10
# 11            139441  Photo         2          12             5         10
# 12            139441  Photo         2          12             5         10
# 13            139441  Photo         2          12             5          3
# 14            138414  Photo         2          12             4          5
# ...

# %% [markdown]
# # STATUS SUBSET

# %%
status_subset = df[df['Type'] == 'Status'].loc[0:20]

# %%
status_subset
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 1             139441  Status         2          12             3         10  \
# 5             139441  Status         2          12             1          9
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
# 15            138414  Status         2          12             3         10
# 18            138414  Status         3          12             2          3
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions
# 1    0.0                      10460                            19057  \
# 5    0.0                      10472                            20849
# 8    0.0                      11844                            22538
# 10   0.0                      21744                            42334
# 15   0.0                      10060                            19680
# ...

# %% [markdown]
# # LINK SUBSET

# %%
link_subset = df[df['Type'] == 'Link'].loc[20:80]

# %%
link_subset
# Out:
#     Page total likes  Type  Category  Post Month  Post Weekday  Post Hour
# 22            138414  Link         1          12             7         10  \
# 41            138895  Link         1          12             6          3
# 43            138353  Link         1          12             5          3
# 45            138353  Link         1          12             4          3
# 47            138353  Link         1          12             3          2
# 49            138353  Link         1          12             2          2
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions
# 22   0.0                       3454                             6853  \
# 41   1.0                      18480                            28438
# 43   1.0                       2645                             4270
# 45   1.0                       7968                            13023
# 47   0.0                       1925                             3481
# ...

# %% [markdown]
# # VIDEO SUBSET

# %%
video_subset = df[df['Type'] == 'Video'].loc[180:300]

# %%
video_subset
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour
# 183            134879  Video         1           9             2         10  \
# 243            130791  Video         1           7             3         11
# 277            126424  Video         1           6             2         13
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions
# 183   0.0                      30624                            56950  \
# 243   1.0                      21872                            40413
# 277   0.0                     139008                           277100
#
#      Lifetime Engaged Users  Lifetime Post Consumers
# 183                    2080                     1956  \
# 243                    3872                     3822
# 277                    1779                     1643
#
#      Lifetime Post Consumptions
# 183                        3253  \
# 243                        7327
# 277                        2356
#
# ...

# %% [markdown]
# # MERGING TWO SUBSETS

# %%
merged_subsets = [photo_subset, video_subset]
merged = pd.concat(merged_subsets)

# %%
merged
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour
# 0              139441  Photo         2          12             4          3  \
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# 7              139441  Photo         3          12             7          9
# 9              139441  Photo         3          12             6         10
# 11             139441  Photo         2          12             5         10
# 12             139441  Photo         2          12             5         10
# 13             139441  Photo         2          12             5          3
# 14             138414  Photo         2          12             4          5
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
merged_subsets = [status_subset, link_subset]
merged = pd.concat(merged_subsets)

# %%
merged
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 1             139441  Status         2          12             3         10  \
# 5             139441  Status         2          12             1          9
# 8             139441  Status         2          12             7          3
# 10            139441  Status         2          12             5         10
# 15            138414  Status         2          12             3         10
# 18            138414  Status         3          12             2          3
# 22            138414    Link         1          12             7         10
# 41            138895    Link         1          12             6          3
# 43            138353    Link         1          12             5          3
# 45            138353    Link         1          12             4          3
# 47            138353    Link         1          12             3          2
# ...

# %% [markdown]
# #  Sorting Data based on Page total likes

# %%
## ASCENDING
sorted_data = df.sort_values('Page total likes')
sorted_data.head(20)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour
# 499             81370  Photo         2           1             4          4  \
# 496             81370  Photo         2           1             5          8
# 498             81370  Photo         3           1             4         11
# 497             81370  Photo         1           1             5          2
# 493             85093  Photo         3           1             1          2
# 495             85093  Photo         3           1             7          2
# 494             85093  Photo         3           1             7         10
# 486             85979  Photo         3           1             1         12
# 487             85979  Photo         3           1             1          2
# 488             85979  Photo         3           1             7         10
# 492             85979   Link         1           1             5         11
# ...

# %%
## DESCENDING
sorted_data = df.sort_values('Page total likes', ascending=False)
sorted_data.head(20)
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0             139441   Photo         2          12             4          3  \
# 8             139441  Status         2          12             7          3
# 1             139441  Status         2          12             3         10
# 12            139441   Photo         2          12             5         10
# 11            139441   Photo         2          12             5         10
# 10            139441  Status         2          12             5         10
# 9             139441   Photo         3          12             6         10
# 13            139441   Photo         2          12             5          3
# 7             139441   Photo         3          12             7          9
# 5             139441  Status         2          12             1          9
# 4             139441   Photo         2          12             2          3
# ...

# %% [markdown]
# #  TRANSPOSING DATA

# %%
transpose_data = df.T
transpose_data
# Out:
#                                                        0       1       2
# Page total likes                                    139441  139441  139441  \
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0            139441   Photo         2          12             4          3  \
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions
# 0   0.0                       2752                             5091  \
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers
# ...

# %% [markdown]
# #  Melting Data to long format

# %%
melted_data = pd.melt(df, id_vars=['Type', 'Category'], value_vars='Total Interactions').loc[0:100]

# %%
melted_data
# Out:
#        Type  Category            variable  value
# 0     Photo         2  Total Interactions    100
# 1    Status         2  Total Interactions    164
# 2     Photo         3  Total Interactions     80
# 3     Photo         2  Total Interactions   1777
# 4     Photo         2  Total Interactions    393
# ..      ...       ...                 ...    ...
# 96    Photo         1  Total Interactions     65
# 97    Photo         2  Total Interactions    142
# 98   Status         2  Total Interactions    378
# 99    Photo         1  Total Interactions    430
# 100   Photo         1  Total Interactions      0
#
# [101 rows x 4 columns]

# %% [markdown]
# # CASTING DATA TO WIDE FORMAT

# %%
#                           index-column,  which columns to choose, what values to choose    
pivot_data = df.pivot_table(index='Type', columns='Category', values='Total Interactions')

# %%
pivot_data
# Out:
# Category           1           2       3
# Type
# Link       91.250000   49.000000   85.00
# Photo     148.789189  283.054945  259.86
# Status    167.666667  224.578947  182.50
# Video     295.857143         NaN     NaN

# %% [markdown]
# # TRIAL

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0            139441   Photo         2          12             4          3  \
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions
# 0   0.0                       2752                             5091  \
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
new_df = df[['Type', 'Category', 'like', 'share', 'Total Interactions']]

# %%
new_df
# Out:
#        Type  Category    like  share  Total Interactions
# 0     Photo         2    79.0   17.0                 100
# 1    Status         2   130.0   29.0                 164
# 2     Photo         3    66.0   14.0                  80
# 3     Photo         2  1572.0  147.0                1777
# 4     Photo         2   325.0   49.0                 393
# ..      ...       ...     ...    ...                 ...
# 495   Photo         3    53.0   26.0                  84
# 496   Photo         2    53.0   22.0                  75
# 497   Photo         1    93.0   18.0                 115
# 498   Photo         3    91.0   38.0                 136
# 499   Photo         2    91.0   28.0                 119
#
# [500 rows x 5 columns]

# %% [markdown]
# # MELTING DATA

# %%
new_melted_data = pd.melt(new_df, id_vars=['Type', 'Category'], value_vars='Total Interactions')

# %%
new_melted_data
# Out:
#        Type  Category            variable  value
# 0     Photo         2  Total Interactions    100
# 1    Status         2  Total Interactions    164
# 2     Photo         3  Total Interactions     80
# 3     Photo         2  Total Interactions   1777
# 4     Photo         2  Total Interactions    393
# ..      ...       ...                 ...    ...
# 495   Photo         3  Total Interactions     84
# 496   Photo         2  Total Interactions     75
# 497   Photo         1  Total Interactions    115
# 498   Photo         3  Total Interactions    136
# 499   Photo         2  Total Interactions    119
#
# [500 rows x 4 columns]

# %% [markdown]
# # CASTING DATA

# %%
new_df
# Out:
#        Type  Category    like  share  Total Interactions
# 0     Photo         2    79.0   17.0                 100
# 1    Status         2   130.0   29.0                 164
# 2     Photo         3    66.0   14.0                  80
# 3     Photo         2  1572.0  147.0                1777
# 4     Photo         2   325.0   49.0                 393
# ..      ...       ...     ...    ...                 ...
# 495   Photo         3    53.0   26.0                  84
# 496   Photo         2    53.0   22.0                  75
# 497   Photo         1    93.0   18.0                 115
# 498   Photo         3    91.0   38.0                 136
# 499   Photo         2    91.0   28.0                 119
#
# [500 rows x 5 columns]

# %%
new_casted_data = df.pivot_table(index='Type', columns='Category', values='Total Interactions')

# %%
new_casted_data
# Out:
# Category           1           2       3
# Type
# Link       91.250000   49.000000   85.00
# Photo     148.789189  283.054945  259.86
# Status    167.666667  224.578947  182.50
# Video     295.857143         NaN     NaN
