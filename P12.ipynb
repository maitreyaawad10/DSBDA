# %%
import pandas as pd

# %%
df = pd.read_csv('./DATASETS/Adult/adult.csv', header=None)

# %%
df.head()
# Out:
#    0                  1       2           3   4                    5
# 0  39          State-gov   77516   Bachelors  13        Never-married  \
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40  \
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
df.columns = ['age', 'workclass', 'fnlwgt', 'education', 'first-num', 'marital-status', 'occupation', 'relationship', 'race',
'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'Income']

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  first-num       marital-status
# 0   39          State-gov   77516   Bachelors         13        Never-married  \
# 1   50   Self-emp-not-inc   83311   Bachelors         13   Married-civ-spouse
# 2   38            Private  215646     HS-grad          9             Divorced
# 3   53            Private  234721        11th          7   Married-civ-spouse
# 4   28            Private  338409   Bachelors         13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain
# 0        Adm-clerical   Not-in-family   White     Male          2174  \
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital-loss  hours-per-week  native-country  Income
# ...

# %%
del df['first-num']

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education       marital-status
# 0   39          State-gov   77516   Bachelors        Never-married  \
# 1   50   Self-emp-not-inc   83311   Bachelors   Married-civ-spouse
# 2   38            Private  215646     HS-grad             Divorced
# 3   53            Private  234721        11th   Married-civ-spouse
# 4   28            Private  338409   Bachelors   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain
# 0        Adm-clerical   Not-in-family   White     Male          2174  \
# 1     Exec-managerial         Husband   White     Male             0
# 2   Handlers-cleaners   Not-in-family   White     Male             0
# 3   Handlers-cleaners         Husband   Black     Male             0
# 4      Prof-specialty            Wife   Black   Female             0
#
#    capital-loss  hours-per-week  native-country  Income
# 0             0              40   United-States   <=50K
# ...

# %%
df.shape
# Out:
# (32561, 14)

# %%
df['sex'].value_counts()
# Out:
# sex
#  Male      21790
#  Female    10771
# Name: count, dtype: int64

# %% [markdown]
# # CREATING DATA SUBSETS

# %%
df['native-country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
df['native-country'] = df['native-country'].replace([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
       ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
       ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
       ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
       ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
       ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
       ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
       ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
       ' Ireland', ' Hungary', ' Holand-Netherlands'], ['United-States', 'Cuba', 'Jamaica', 'India', '?', 'Mexico',
       'South', 'Puerto-Rico', 'Honduras', 'England', 'Canada',
       'Germany', 'Iran', 'Philippines', 'Italy', 'Poland',
       'Columbia', 'Cambodia', 'Thailand', 'Ecuador', 'Laos',
       'Taiwan', 'Haiti', 'Portugal', 'Dominican-Republic',
       'El-Salvador', 'France', 'Guatemala', 'China', 'Japan',
       'Yugoslavia', 'Peru', 'Outlying-US(Guam-USVI-etc)', 'Scotland',
       'Trinadad&Tobago', 'Greece', 'Nicaragua', 'Vietnam', 'Hong',
       'Ireland', 'Hungary', 'Holand-Netherlands'])

# %%
india_subset = df.loc[df['native-country'] == 'India']
india_subset.head()
# Out:
#       age          workclass  fnlwgt   education          marital-status
# 11     30          State-gov  141297   Bachelors      Married-civ-spouse  \
# 892    28            Private  164170   Assoc-voc      Married-civ-spouse
# 968    48            Private  164966   Bachelors      Married-civ-spouse
# 1029   48       Self-emp-inc  138370     Masters   Married-spouse-absent
# 1095   22   Self-emp-not-inc  361280   Bachelors           Never-married
#
#             occupation    relationship                race     sex
# 11      Prof-specialty         Husband  Asian-Pac-Islander    Male  \
# 892       Adm-clerical            Wife  Asian-Pac-Islander  Female
# 968    Exec-managerial         Husband  Asian-Pac-Islander    Male
# 1029             Sales   Not-in-family  Asian-Pac-Islander    Male
# 1095    Prof-specialty       Own-child  Asian-Pac-Islander    Male
#
#       capital-gain  capital-loss  hours-per-week native-country  Income
# ...

# %%
usa_subset = df.loc[df['native-country'] == 'United-States']
usa_subset.head()
# Out:
#    age          workclass  fnlwgt   education       marital-status
# 0   39          State-gov   77516   Bachelors        Never-married  \
# 1   50   Self-emp-not-inc   83311   Bachelors   Married-civ-spouse
# 2   38            Private  215646     HS-grad             Divorced
# 3   53            Private  234721        11th   Married-civ-spouse
# 5   37            Private  284582     Masters   Married-civ-spouse
#
#            occupation    relationship   race     sex  capital-gain
# 0        Adm-clerical   Not-in-family  White    Male          2174  \
# 1     Exec-managerial         Husband  White    Male             0
# 2   Handlers-cleaners   Not-in-family  White    Male             0
# 3   Handlers-cleaners         Husband  Black    Male             0
# 5     Exec-managerial            Wife  White  Female             0
#
#    capital-loss  hours-per-week native-country  Income
# 0             0              40  United-States   <=50K
# ...

# %%
df['sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
df['sex'] = df['sex'].replace([' Male', ' Female'], ['Male', 'Female'])

# %%
df['sex'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
male_subset = df.loc[df['sex'] == 'Male']
male_subset.head()
# Out:
#    age          workclass  fnlwgt   education       marital-status
# 0   39          State-gov   77516   Bachelors        Never-married  \
# 1   50   Self-emp-not-inc   83311   Bachelors   Married-civ-spouse
# 2   38            Private  215646     HS-grad             Divorced
# 3   53            Private  234721        11th   Married-civ-spouse
# 7   52   Self-emp-not-inc  209642     HS-grad   Married-civ-spouse
#
#            occupation    relationship    race   sex  capital-gain
# 0        Adm-clerical   Not-in-family   White  Male          2174  \
# 1     Exec-managerial         Husband   White  Male             0
# 2   Handlers-cleaners   Not-in-family   White  Male             0
# 3   Handlers-cleaners         Husband   Black  Male             0
# 7     Exec-managerial         Husband   White  Male             0
#
#    capital-loss  hours-per-week  native-country  Income
# 0             0              40   United-States   <=50K
# ...

# %%
female_subset = df.loc[df['sex'] == 'Female']
female_subset.head()
# Out:
#     age workclass  fnlwgt   education          marital-status
# 4    28   Private  338409   Bachelors      Married-civ-spouse  \
# 5    37   Private  284582     Masters      Married-civ-spouse
# 6    49   Private  160187         9th   Married-spouse-absent
# 8    31   Private   45781     Masters           Never-married
# 12   23   Private  122272   Bachelors           Never-married
#
#           occupation    relationship    race     sex  capital-gain
# 4     Prof-specialty            Wife   Black  Female             0  \
# 5    Exec-managerial            Wife   White  Female             0
# 6      Other-service   Not-in-family   Black  Female             0
# 8     Prof-specialty   Not-in-family   White  Female         14084
# 12      Adm-clerical       Own-child   White  Female             0
#
#     capital-loss  hours-per-week  native-country  Income
# 4              0              40            Cuba   <=50K
# 5              0              40   United-States   <=50K
# ...

# %%
df['race'].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
df['race'] = df['race'].replace([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
       ' Other'], ['White', 'Black', 'Asian-Pac-Islander', 'Amer-Indian-Eskimo',
       'Other'])

# %%
race_white = df[df['race'] == 'White']
race_white.head()
# Out:
#    age          workclass  fnlwgt   education       marital-status
# 0   39          State-gov   77516   Bachelors        Never-married  \
# 1   50   Self-emp-not-inc   83311   Bachelors   Married-civ-spouse
# 2   38            Private  215646     HS-grad             Divorced
# 5   37            Private  284582     Masters   Married-civ-spouse
# 7   52   Self-emp-not-inc  209642     HS-grad   Married-civ-spouse
#
#            occupation    relationship   race     sex  capital-gain
# 0        Adm-clerical   Not-in-family  White    Male          2174  \
# 1     Exec-managerial         Husband  White    Male             0
# 2   Handlers-cleaners   Not-in-family  White    Male             0
# 5     Exec-managerial            Wife  White  Female             0
# 7     Exec-managerial         Husband  White    Male             0
#
#    capital-loss  hours-per-week native-country  Income
# 0             0              40  United-States   <=50K
# ...

# %%
race_black = df[df['race'] == 'Black']
race_black.head()
# Out:
#     age workclass  fnlwgt      education          marital-status
# 3    53   Private  234721           11th      Married-civ-spouse  \
# 4    28   Private  338409      Bachelors      Married-civ-spouse
# 6    49   Private  160187            9th   Married-spouse-absent
# 10   37   Private  280464   Some-college      Married-civ-spouse
# 13   32   Private  205019     Assoc-acdm           Never-married
#
#             occupation    relationship   race     sex  capital-gain
# 3    Handlers-cleaners         Husband  Black    Male             0  \
# 4       Prof-specialty            Wife  Black  Female             0
# 6        Other-service   Not-in-family  Black  Female             0
# 10     Exec-managerial         Husband  Black    Male             0
# 13               Sales   Not-in-family  Black    Male             0
#
#     capital-loss  hours-per-week native-country  Income
# 3              0              40  United-States   <=50K
# ...

# %% [markdown]
# # MERGING TWO SUBSETS

# %%
merged_subset = pd.concat([india_subset, race_white])
merged_subset
# Out:
#        age          workclass  fnlwgt    education          marital-status
# 11      30          State-gov  141297    Bachelors      Married-civ-spouse  \
# 892     28            Private  164170    Assoc-voc      Married-civ-spouse
# 968     48            Private  164966    Bachelors      Married-civ-spouse
# 1029    48       Self-emp-inc  138370      Masters   Married-spouse-absent
# 1095    22   Self-emp-not-inc  361280    Bachelors           Never-married
# ...    ...                ...     ...          ...                     ...
# 32556   27            Private  257302   Assoc-acdm      Married-civ-spouse
# 32557   40            Private  154374      HS-grad      Married-civ-spouse
# 32558   58            Private  151910      HS-grad                 Widowed
# 32559   22            Private  201490      HS-grad           Never-married
# 32560   52       Self-emp-inc  287927      HS-grad      Married-civ-spouse
#
# ...

# %% [markdown]
# # MELTING DATA TO LONG FORMAT

# %%
melted_data = pd.melt(df, id_vars=['workclass', 'education'], value_vars='Income')
melted_data
# Out:
#                workclass    education variable   value
# 0              State-gov    Bachelors   Income   <=50K
# 1       Self-emp-not-inc    Bachelors   Income   <=50K
# 2                Private      HS-grad   Income   <=50K
# 3                Private         11th   Income   <=50K
# 4                Private    Bachelors   Income   <=50K
# ...                  ...          ...      ...     ...
# 32556            Private   Assoc-acdm   Income   <=50K
# 32557            Private      HS-grad   Income    >50K
# 32558            Private      HS-grad   Income   <=50K
# 32559            Private      HS-grad   Income   <=50K
# 32560       Self-emp-inc      HS-grad   Income    >50K
#
# [32561 rows x 4 columns]

# %% [markdown]
# # CASTING DATA TO WIDE FORMAT

# %%
casted_data = df.pivot_table(index=['workclass', 'education'], columns='sex', values='Income')
casted_data
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1489             try:
# -> 1490                 result = self.grouper._cython_operation(
#    1491                     "aggregate",
#
# ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958         ngroups = self.ngroups
# --> 959         return cy_op.cython_operation(
#     960             values=values,
#
# ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     656
# --> 657         return self._cython_op_ndim_compat(
#     658             values,
#
# ...

# %%
df['Income'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
df['Income'] = df['Income'].replace([' <=50K', ' >50K'], [1, 2])

# %%
df['Income'].unique()
# Out:
# array([1, 2])

# %%
casted_data = df.pivot_table(index='workclass', columns='education', values='Income')
casted_data.tail()
# Out:
# education              10th      11th      12th   1st-4th   5th-6th   7th-8th
# workclass
#  Private           1.067626  1.048754  1.069069  1.036765  1.026316  1.042453  \
#  Self-emp-inc      1.157895  1.285714  1.142857  1.000000  1.500000  1.357143
#  Self-emp-not-inc  1.104478  1.116667  1.157895  1.076923  1.210526  1.148936
#  State-gov         1.153846  1.071429  1.200000  1.000000  1.000000  1.000000
#  Without-pay            NaN       NaN       NaN       NaN       NaN  1.000000
#
# education               9th   Assoc-acdm   Assoc-voc   Bachelors   Doctorate
# workclass
#  Private           1.046512     1.233196    1.254726    1.421008    1.729282  \
#  Self-emp-inc      1.000000     1.514286    1.500000    1.626374    1.828571
#  Self-emp-not-inc  1.117647     1.253521    1.194444    1.408521    1.620000
#  State-gov         1.000000     1.146341    1.260870    1.333333    1.797753
#  Without-pay            NaN     1.000000         NaN         NaN         NaN
#
# ...
